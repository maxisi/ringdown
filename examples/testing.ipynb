# %%
# %pylab inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import seaborn as sns

import gwtones

from importlib import reload

# %%
m = (1, -2, 2, 2, 0)
gwtones.qnms.KerrMode(**dict(zip(['p', 's', 'l', 'm', 'n'], m)))

# %%
chis = linspace(0, 5, 10, endpoint=False)

# %%
mode2 = gwtones.qnms.KerrMode(1, -2, 2, 2, 0)

# %%
chis = linspace(0, 1, 10, endpoint=False)

for n in range(4):
    c = sns.color_palette()[n]
    mode = gwtones.qnms.KerrMode(1, -2, 2, 2, n)
    scatter(chis, mode.ftau(chis)[0], marker='o', facecolor='w', ec=c)
    scatter(chis, mode.ftau(chis, approx=True)[0], marker='+', c=c)
xlabel(r'$\chi$')
ylabel()
# Out:
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %%
# %time
mode.ftau(0.69, 69, approx=True)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# (241.0708332978867, 0.0013788616192769824)

# %%
array(1, ndmin=1)[0]
# Out:
# 1

# %%
a = array(1)

# %%
for j in list(a):
    print(j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-c6bf334810c4> in <module>
# ----> 1 for j in list(a):
#       2     print(j)
#
# TypeError: iteration over a 0-d array

# %%
a=9
a[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-4a0962a5fa7b> in <module>
#       1 a=9
# ----> 2 a[0]
#
# TypeError: 'int' object is not subscriptable

# %%
reload(gwtones.fit)
# Out:
# <module 'gwtones.fit' from '/Users/maxisi/src/gwtones/gwtones/fit.py'>

# %%
fit = gwtones.fit.Fit('kerr')

# %%
fit.set_tone_sequence(2)

# %%
fit.coeffs
# Out:
# (array([[-0.00823557,  0.05994978, -0.00106621,  0.08354181, -0.15165638,
#           0.11021346],
#         [-0.00817462,  0.05566214,  0.00174686,  0.08531498, -0.15464552,
#           0.11325923]]),
#  array([[ 0.01180702,  0.08838127,  0.02528302, -0.09002286,  0.18245511,
#          -0.12162592],
#         [ 0.03544845,  0.27212686,  0.0702625 , -0.27797961,  0.55851284,
#          -0.36945098]]))

# %%
fit.coeffs
# Out:
# (array([[-0.00823557,  0.05994978, -0.00106621,  0.08354181, -0.15165638,
#           0.11021346],
#         [-0.00817462,  0.05566214,  0.00174686,  0.08531498, -0.15464552,
#           0.11325923]]),
#  array([[ 0.01180702,  0.08838127,  0.02528302, -0.09002286,  0.18245511,
#          -0.12162592],
#         [ 0.03544845,  0.27212686,  0.0702625 , -0.27797961,  0.55851284,
#          -0.36945098]]))
